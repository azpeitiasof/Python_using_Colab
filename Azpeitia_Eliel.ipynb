# %% [markdown]
# <a href="https://colab.research.google.com/github/azpeitiasof/Python_using_Colab/blob/main/Azpeitia_Eliel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # nos permite cargar datos como archivos de excel (formatos .xlsx y .csv)
import matplotlib.pyplot as plt # Nos permite realizar gráficos con python
import seaborn as sns

# %%
dataset = pd.read_excel('Latam Christmas Gifts Dataset.xlsx')

# %%
dataset.head(5)
# Out:
#    id  age      country       gift_name gift_type  gender  price
# 0   1   11      Ecuador     Soccer Ball      Toys  Female      7
# 1   2   14   Costa Rica        Lego Set      Toys  Female      8
# 2   3    9  Puerto Rico            Doll      Toys  Female     54
# 3   4    4    Argentina  Stuffed Animal      Toys  Female     26
# 4   5    8    Guatemala            Doll      Toys  Female     56

# %%
Regalos = dataset.groupby(['gift_name'])['age'].mean().sort_values(ascending=False)
Regalos.head(5)
# Out:
# gift_name
# Jeans                 12.500000
# Headphones            12.476190
# Video Game Console    12.471698
# Tablet                12.469388
# Shoes                 11.866667
# Name: age, dtype: float64

# %%
filtro = dataset['gift_type'] == 'Electronics'
df_filtrado = dataset[filtro]
paises = df_filtrado.groupby('country')['country'].count().sort_values(ascending=False)
paises.head()
# Out:
# country
# Chile          11
# Paraguay       11
# Uruguay        10
# Ecuador        10
# Puerto Rico     9
# Name: country, dtype: int64

# %%
eco = dataset ['price'] < 20
econo = dataset[eco]
economico = econo.groupby(['gift_name'])['price'].sum().sort_values(ascending=True)
economico.head(5)
# Out:
# gift_name
# Tshirt               19
# Princess Costume     22
# Superhero Costume    32
# Shoes                41
# Stuffed Animal       42
# Name: price, dtype: int64

# %%
Regalos.plot(kind='bar', title='Regalos por edad mas solicitados')
# Out:
# <Axes: title={'center': 'Regalos por edad mas solicitados'}, xlabel='gift_name'>

# %%
paises.plot(kind='bar', title='Lista de paises que mas regalos solicitan')
# Out:
# <Axes: title={'center': 'Lista de paises que mas regalos solicitan'}, xlabel='country'>

# %%
economico.plot(kind='bar', title='Lista de regalos: Del mas economico al mas caro')
# Out:
# <Axes: title={'center': 'Lista de regalos: Del mas economico al mas caro'}, xlabel='gift_name'>
